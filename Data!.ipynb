# %%
import pandas as pd

alabama = pd.read_csv('./States/data/alabama.csv')
alaska = pd.read_csv('./States/data/alaska.csv')
arizona = pd.read_csv('./States/data/arizona.csv')
arkansas = pd.read_csv('./States/data/arkansas.csv')
california = pd.read_csv('./States/data/california.csv')
colorado = pd.read_csv('./States/data/colorado.csv')
connecticut = pd.read_csv('./States/data/connecticut.csv')
delaware = pd.read_csv('./States/data/delaware.csv')
florida = pd.read_csv('./States/data/florida.csv')
georgia = pd.read_csv('./States/data/georgia.csv')
hawaii = pd.read_csv('./States/data/hawaii.csv')
idaho = pd.read_csv('./States/data/idaho.csv')
illinois = pd.read_csv('./States/data/illinois.csv')
indiana = pd.read_csv('./States/data/indiana.csv')
iowa = pd.read_csv('./States/data/iowa.csv')
kansas = pd.read_csv('./States/data/kansas.csv')
kentucky = pd.read_csv('./States/data/kentucky.csv')
louisiana = pd.read_csv('./States/data/louisiana.csv')
maine = pd.read_csv('./States/data/maine.csv')
maryland = pd.read_csv('./States/data/maryland.csv')
massachusetts = pd.read_csv('./States/data/massachusetts.csv')
michigan = pd.read_csv('./States/data/michigan.csv')
minnesota = pd.read_csv('./States/data/minnesota.csv')
mississippi = pd.read_csv('./States/data/mississippi.csv')
missouri = pd.read_csv('./States/data/missouri.csv')
montana = pd.read_csv('./States/data/montana.csv')
nebraska = pd.read_csv('./States/data/nebraska.csv')
nevada = pd.read_csv('./States/data/nevada.csv')
new_hampshire = pd.read_csv('./States/data/newhampshire.csv')
new_jersey = pd.read_csv('./States/data/newjersey.csv')
new_mexico = pd.read_csv('./States/data/newmexico.csv')
new_york = pd.read_csv('./States/data/newyork.csv')
north_carolina = pd.read_csv('./States/data/northcarolina.csv')
north_dakota = pd.read_csv('./States/data/northdakota.csv')
ohio = pd.read_csv('./States/data/ohio.csv')
oklahoma = pd.read_csv('./States/data/oklahoma.csv')
oregon = pd.read_csv('./States/data/oregon.csv')
pennsylvania = pd.read_csv('./States/data/pennsylvania.csv')
rhode_island = pd.read_csv('./States/data/rhodeisland.csv')
south_carolina = pd.read_csv('./States/data/southcarolina.csv')
south_dakota = pd.read_csv('./States/data/southdakota.csv')
tennessee = pd.read_csv('./States/data/tennessee.csv')
texas = pd.read_csv('./States/data/texas.csv')
utah = pd.read_csv('./States/data/utah.csv')
vermont = pd.read_csv('./States/data/vermont.csv')
virginia = pd.read_csv('./States/data/virginia.csv')
washington = pd.read_csv('./States/data/washington.csv')
west_virginia = pd.read_csv('./States/data/westvirginia.csv')
wisconsin = pd.read_csv('./States/data/wisconsin.csv')
wyoming = pd.read_csv('./States/data/wyoming.csv')
dc = pd.read_csv('./States/data/dc.csv')

# %%
usa = pd.concat([alabama, alaska, arizona, arkansas, california,
                colorado, connecticut, delaware, florida, georgia,
                hawaii, idaho, illinois, indiana, iowa,
                kansas, kentucky, louisiana, maine, maryland,
                massachusetts, michigan, minnesota, mississippi, missouri,
                montana, nebraska, nevada, new_hampshire, new_jersey,
                new_mexico, new_york, north_carolina, north_dakota, ohio,
                oklahoma, oregon, pennsylvania, rhode_island, south_carolina,
                south_dakota, tennessee, texas, utah, vermont,
                virginia, washington, west_virginia, wisconsin, wyoming, dc], ignore_index=True)
print(usa.shape)
usa.head()
# Out:
# (24296, 10)
# C:\Users\anika\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.
#   City Name City Name_link            Name  \
# 0       NaN            NaN   Abbeville, AL
# 1       NaN            NaN        Abernant
# 2       NaN            NaN  Adamsville, AL
# 3       NaN            NaN     Addison, AL
# 4       NaN            NaN       Akron, AL
#
#                                            Name_link Population  URL URL_link  \
# 0                                                NaN        NaN  NaN      NaN
# 1  https://www.city-data.com/city/Abernant-Alabam...        NaN  NaN      NaN
# ...

# %%
usa = usa.drop(['Population', 'url'], axis = 1)

# %%
usa.head()
# Out:
#   City Name City Name_link            Name  \
# 0       NaN            NaN   Abbeville, AL
# 1       NaN            NaN        Abernant
# 2       NaN            NaN  Adamsville, AL
# 3       NaN            NaN     Addison, AL
# 4       NaN            NaN       Akron, AL
#
#                                            Name_link  URL URL_link URLs  \
# 0                                                NaN  NaN      NaN  NaN
# 1  https://www.city-data.com/city/Abernant-Alabam...  NaN      NaN  NaN
# 2                                                NaN  NaN      NaN  NaN
# 3                                                NaN  NaN      NaN  NaN
# 4                                                NaN  NaN      NaN  NaN
#
#   URLs_link
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
usa["city"] = usa['City Name'].map(str) + usa['Name'].map(str)
usa["link"] = usa['City Name_link'].map(str) + usa['Name_link'].map(str) + usa['URL_link'].map(str) + usa['URLs_link'].map(str)

usa.head()
# Out:
#   City Name City Name_link            Name  \
# 0       NaN            NaN   Abbeville, AL
# 1       NaN            NaN        Abernant
# 2       NaN            NaN  Adamsville, AL
# 3       NaN            NaN     Addison, AL
# 4       NaN            NaN       Akron, AL
#
#                                            Name_link  URL URL_link URLs  \
# 0                                                NaN  NaN      NaN  NaN
# 1  https://www.city-data.com/city/Abernant-Alabam...  NaN      NaN  NaN
# 2                                                NaN  NaN      NaN  NaN
# 3                                                NaN  NaN      NaN  NaN
# 4                                                NaN  NaN      NaN  NaN
#
#   URLs_link               city  \
# 0       NaN   nanAbbeville, AL
# 1       NaN        nanAbernant
# 2       NaN  nanAdamsville, AL
# 3       NaN     nanAddison, AL
# 4       NaN       nanAkron, AL
#
#                                                 link
# ...

# %%
usa = usa.drop(['City Name', 'City Name_link', 'Name', 'Name_link', 'URL', "URL_link", 'URLs', 'URLs_link'], axis = 1)

# %%
usa.head()
# Out:
#                 city                                               link
# 0   nanAbbeville, AL                                       nannannannan
# 1        nanAbernant  nanhttps://www.city-data.com/city/Abernant-Ala...
# 2  nanAdamsville, AL                                       nannannannan
# 3     nanAddison, AL                                       nannannannan
# 4       nanAkron, AL                                       nannannannan

# %%
import numpy as np

usa = usa.replace('nannannannan', np.nan)
usa.head()
# Out:
#                 city                                               link
# 0   nanAbbeville, AL                                                NaN
# 1        nanAbernant  nanhttps://www.city-data.com/city/Abernant-Ala...
# 2  nanAdamsville, AL                                                NaN
# 3     nanAddison, AL                                                NaN
# 4       nanAkron, AL                                                NaN

# %%
usa = usa.dropna()
usa.head()
# Out:
#                   city                                               link
# 1          nanAbernant  nanhttps://www.city-data.com/city/Abernant-Ala...
# 5         nanAlabaster  nanhttps://www.city-data.com/city/Alabaster-Al...
# 7   nanAlbertville, AL  nanhttps://www.city-data.com/city/Albertville-...
# 8    nanAlexander City  nanhttps://www.city-data.com/city/Alexander-Ci...
# 13    nanAndalusia, AL  nanhttps://www.city-data.com/city/Andalusia-Al...

# %%
usa.shape
# Out:
# (6889, 2)

# %%
for item in usa['city']:
    if item.startswith('nan'):
        item = item[3:]
    elif item.endswith('nan'):
        item = item[:-3]
    else:
        continue
        
usa.head()
# Out:
#                   city                                               link
# 1          nanAbernant  nanhttps://www.city-data.com/city/Abernant-Ala...
# 5         nanAlabaster  nanhttps://www.city-data.com/city/Alabaster-Al...
# 7   nanAlbertville, AL  nanhttps://www.city-data.com/city/Albertville-...
# 8    nanAlexander City  nanhttps://www.city-data.com/city/Alexander-Ci...
# 13    nanAndalusia, AL  nanhttps://www.city-data.com/city/Andalusia-Al...

# %%
usa['city'] = usa['city'].map(lambda x: x.lstrip('nan').rstrip('nan'))
usa['link'] = usa['link'].map(lambda x: x.lstrip('nan').rstrip('nannan'))

# %%
usa.sample(10)
# Out:
#                  city                                               link
# 4038         Dahloneg  https://www.city-data.com/city/Dahlonega-Georg...
# 22277  Mill Creek, WA  https://www.city-data.com/city/Mill-Creek-Wash...
# 5703                   https://www.city-data.com/city/Rochelle-Illino...
# 23899                  https://www.city-data.com/city/Portage-Wiscons...
# 2267      Edwards, CO  https://www.city-data.com/city/Edwards-Colorad...
# 3861                   https://www.city-data.com/city/West-Park-Flori...
# 16905            Cole  https://www.city-data.com/city/Collinsville-Ok...
# 4241              New  https://www.city-data.com/city/Newnan-Georgia....
# 23771                  https://www.city-data.com/city/Neenah-Wisconsi...
# 5622                   https://www.city-data.com/city/Park-City-Illin...

# %%
usa = usa.replace('', np.nan)
usa.sample(10)
# Out:
#                    city                                               link
# 14131      Cornwall, NY  https://www.city-data.com/city/Cornwall-New-Yo...
# 11683               NaN  https://www.city-data.com/city/Sappington-Miss...
# 21607       Cherry Hill  https://www.city-data.com/city/Cherry-Hill-Vir...
# 21883    Waynesboro, VA  https://www.city-data.com/city/Waynesboro-Virg...
# 16376               NaN    https://www.city-data.com/city/Geneva-Ohio.html
# 3145                NaN  https://www.city-data.com/city/Florida-City-Fl...
# 21610       Chester, VA  https://www.city-data.com/city/Chester-Virgini...
# 6294                NaN  https://www.city-data.com/city/Martinsville-In...
# 4091   Fayetteville, GA  https://www.city-data.com/city/Fayetteville-Ge...
# 1961      Riverside, CA  https://www.city-data.com/city/Riverside-Calif...

# %%
usa = usa.dropna()
print(usa.shape)
usa.head()
# Out:
# (4750, 2)
#                city                                               link
# 1          Abernant  https://www.city-data.com/city/Abernant-Alabam...
# 5         Alabaster  https://www.city-data.com/city/Alabaster-Alaba...
# 7   Albertville, AL  https://www.city-data.com/city/Albertville-Ala...
# 8    Alexander City  https://www.city-data.com/city/Alexander-City-...
# 13    Andalusia, AL  https://www.city-data.com/city/Andalusia-Alaba...

# %%
pd.set_option('display.max_colwidth', -1)
usa.sample(10)
# Out:
#                        city  \
# 1905   Paradise, CA
# 9616   Birmingham, MI
# 20572  Graham, TX
# 13181  Milltown, NJ
# 1738   La Canada Flintridge
# 1979   Salinas, CA
# 20406  Clute
# 4227   Morrow, GA
# 8367   Jennings, LA
# 1025   Yuma, AZ
#
#                                                                       link
# 1905   https://www.city-data.com/city/Paradise-California.html
# 9616   https://www.city-data.com/city/Birmingham-Michigan.html
# 20572  https://www.city-data.com/city/Graham-Texas.html
# 13181  https://www.city-data.com/city/Milltown-New-Jersey.html
# 1738   https://www.city-data.com/city/La-Canada-Flintridge-California.html
# 1979   https://www.city-data.com/city/Salinas-California.html
# 20406  https://www.city-data.com/city/Clute-Texas.html
# 4227   https://www.city-data.com/city/Morrow-Georgia.html
# 8367   https://www.city-data.com/city/Jennings-Louisiana.html
# 1025   https://www.city-data.com/city/Yuma-Arizona.html

# %%
usa = usa.reset_index(drop=True)
usa.sample(10)
# Out:
#                   city  \
# 1665  Moss Bluff
# 776   Poway
# 1326  Fort Valley, GA
# 4034  Euless
# 4093  Houston, TX
# 2344  Beatrice, NE
# 1683  River Ridge, LA
# 2100  Rehoboth
# 4474  Purcellville
# 471   East San Gabriel
#
#                                                                  link
# 1665  https://www.city-data.com/city/Moss-Bluff-Louisiana.html
# 776   https://www.city-data.com/city/Poway-California.html
# 1326  https://www.city-data.com/city/Fort-Valley-Georgia.html
# 4034  https://www.city-data.com/city/Euless-Texas.html
# 4093  https://www.city-data.com/city/Houston-Texas.html
# 2344  https://www.city-data.com/city/Beatrice-Nebraska.html
# 1683  https://www.city-data.com/city/River-Ridge-Louisiana.html
# 2100  https://www.city-data.com/city/Rehoboth-Massachusetts.html
# 4474  https://www.city-data.com/city/Purcellville-Virginia.html
# 471   https://www.city-data.com/city/East-San-Gabriel-California.html

# %%
usa.head(20)
# Out:
#                      city  \
# 0   Abernant
# 1   Alabaster
# 2   Albertville, AL
# 3   Alexander City
# 4   Andalusia, AL
# 5   Anniston, AL
# 6   Arab
# 7   Athens, AL
# 8   Atmore
# 9   Auburn, AL
# 10  Bay Minette
# 11  Beauregard-Marvy
# 12  Bessemer, AL
# 13  Beulah, AL
# 14  Big Sandy-Duncanville
# 15  Birmingham, AL
# 16  Boaz, AL
# 17  Bremen, AL
# 18  Brook Highland
# 19  Calera, AL
#
#                                                                  link
# 0   https://www.city-data.com/city/Abernant-Alabama.html
# 1   https://www.city-data.com/city/Alabaster-Alabama.html
# 2   https://www.city-data.com/city/Albertville-Alabama.html
# 3   https://www.city-data.com/city/Alexander-City-Alabama.html
# 4   https://www.city-data.com/city/Andalusia-Alabama.html
# 5   https://www.city-data.com/city/Anniston-Alabama.html
# 6   https://www.city-data.com/city/Arab-Alabama.html
# 7   https://www.city-data.com/city/Athens-Alabama.html
# ...

# %%
usa.to_csv('cities.csv')
